# %% [markdown]
# # EBAC - Regressão II - regressão múltipla
#
# ## Tarefa I

# %% [markdown]
# #### Previsão de renda
#
# Vamos trabalhar com a base 'previsao_de_renda.csv', que é a base do seu próximo projeto. Vamos usar os recursos que vimos até aqui nesta base.
#
# |variavel|descrição|
# |-|-|
# |data_ref                | Data de referência de coleta das variáveis |
# |index                   | Código de identificação do cliente|
# |sexo                    | Sexo do cliente|
# |posse_de_veiculo        | Indica se o cliente possui veículo|
# |posse_de_imovel         | Indica se o cliente possui imóvel|
# |qtd_filhos              | Quantidade de filhos do cliente|
# |tipo_renda              | Tipo de renda do cliente|
# |educacao                | Grau de instrução do cliente|
# |estado_civil            | Estado civil do cliente|
# |tipo_residencia         | Tipo de residência do cliente (própria, alugada etc)|
# |idade                   | Idade do cliente|
# |tempo_emprego           | Tempo no emprego atual|
# |qt_pessoas_residencia   | Quantidade de pessoas que moram na residência|
# |renda                   | Renda em reais|

# %%
import pandas as pd

import seaborn as sns
from seaborn import load_dataset
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import patsy
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %matplotlib inline

# %%
df = pd.read_csv('previsao_de_renda.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             15000 non-null  int64
#  1   data_ref               15000 non-null  object
#  2   id_cliente             15000 non-null  int64
#  3   sexo                   15000 non-null  object
#  4   posse_de_veiculo       15000 non-null  bool
#  5   posse_de_imovel        15000 non-null  bool
#  6   qtd_filhos             15000 non-null  int64
#  7   tipo_renda             15000 non-null  object
#  8   educacao               15000 non-null  object
#  9   estado_civil           15000 non-null  object
#  10  tipo_residencia        15000 non-null  object
#  11  idade                  15000 non-null  int64
#  12  tempo_emprego          12427 non-null  float64
#  13  qt_pessoas_residencia  15000 non-null  float64
#  14  renda                  15000 non-null  float64
# dtypes: bool(2), float64(3), int64(4), object(6)
# memory usage: 1.5+ MB

# %% [markdown]
# 1. Ajuste um modelo para prever log(renda) considerando todas as covariáveis disponíveis.
#     - Utilizando os recursos do Patsy, coloque as variáveis qualitativas como *dummies*.
#     - Mantenha sempre a categoria mais frequente como casela de referência
#     - Avalie os parâmetros e veja se parecem fazer sentido prático.
#
#
# 2. Remova a variável menos significante e analise:
#     - Observe os indicadores que vimos, e avalie se o modelo melhorou ou piorou na sua opinião.
#     - Observe os parâmetros e veja se algum se alterou muito.
#
#
# 3. Siga removendo as variáveis menos significantes, sempre que o *p-value* for menor que 5%. Compare o modelo final com o inicial. Observe os indicadores e conclua se o modelo parece melhor.

# %%
df['tipo_residencia'].value_counts()
# Out:
# tipo_residencia
# Casa             13532
# Com os pais        675
# Governamental      452
# Aluguel            194
# Estúdio             83
# Comunitário         64
# Name: count, dtype: int64

# %%
colunas = list(df.columns)
regr1 = smf.ols("""np.log(renda) ~ C(data_ref) + id_cliente + C(sexo) + posse_de_veiculo + posse_de_imovel + qtd_filhos + 
                C(tipo_renda) + C(educacao, Treatment(2)) + C(estado_civil) + C(tipo_residencia, Treatment(1)) + tempo_emprego 
                + qt_pessoas_residencia""", data = df).fit()
regr1.summary()

# As variáveis que necessitavam de mudança no parâmetro "Treatment" receberam a devida alteração. As demais, que já estavam corretas
# por padrão, foram preservadas.
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          np.log(renda)   R-squared:                       0.357
# Model:                            OLS   Adj. R-squared:                  0.355
# Method:                 Least Squares   F-statistic:                     180.9
# Date:                Fri, 09 Aug 2024   Prob (F-statistic):               0.00
# Time:                        17:20:08   Log-Likelihood:                -13574.
# No. Observations:               12427   AIC:                         2.723e+04
# Df Residuals:                   12388   BIC:                         2.751e+04
# Df Model:                          38
# Covariance Type:            nonrobust
# =====================================================================================================================
#                                                         coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------
# Intercept                                             6.7514      0.219     30.896      0.000       6.323       7.180
# C(data_ref)[T.2015-02-01]                             0.0019      0.035      0.053      0.958      -0.068       0.071
# C(data_ref)[T.2015-03-01]                             0.0483      0.036      1.358      0.175      -0.021       0.118
# C(data_ref)[T.2015-04-01]                             0.0487      0.035      1.372      0.170      -0.021       0.118
# C(data_ref)[T.2015-05-01]                            -0.0192      0.035     -0.544      0.586      -0.089       0.050
# C(data_ref)[T.2015-06-01]                             0.0713      0.036      2.008      0.045       0.002       0.141
# C(data_ref)[T.2015-07-01]                             0.0285      0.035      0.805      0.421      -0.041       0.098
# C(data_ref)[T.2015-08-01]                            -0.0004      0.036     -0.011      0.991      -0.070       0.069
# C(data_ref)[T.2015-09-01]                            -0.0092      0.035     -0.259      0.795      -0.078       0.060
# C(data_ref)[T.2015-10-01]                             0.0223      0.036      0.626      0.531      -0.047       0.092
# C(data_ref)[T.2015-11-01]                             0.0224      0.036      0.630      0.528      -0.047       0.092
# C(data_ref)[T.2015-12-01]                             0.0720      0.036      2.017      0.044       0.002       0.142
# C(data_ref)[T.2016-01-01]                            -0.0391      0.036     -1.101      0.271      -0.109       0.031
# C(data_ref)[T.2016-02-01]                            -0.0039      0.036     -0.110      0.912      -0.074       0.066
# C(data_ref)[T.2016-03-01]                            -0.0391      0.036     -1.091      0.275      -0.109       0.031
# C(sexo)[T.M]                                          0.7826      0.015     53.418      0.000       0.754       0.811
# posse_de_veiculo[T.True]                              0.0384      0.014      2.708      0.007       0.011       0.066
# posse_de_imovel[T.True]                               0.0873      0.014      6.225      0.000       0.060       0.115
# C(tipo_renda)[T.Bolsista]                             0.2336      0.242      0.966      0.334      -0.240       0.707
# C(tipo_renda)[T.Empresário]                           0.1537      0.015     10.280      0.000       0.124       0.183
# C(tipo_renda)[T.Pensionista]                         -0.3042      0.242     -1.258      0.208      -0.778       0.170
# C(tipo_renda)[T.Servidor público]                     0.0561      0.022      2.521      0.012       0.012       0.100
# C(educacao, Treatment(2))[T.Primário]                 0.0021      0.072      0.030      0.976      -0.139       0.143
# C(educacao, Treatment(2))[T.Pós graduação]            0.1224      0.142      0.860      0.390      -0.157       0.401
# C(educacao, Treatment(2))[T.Superior completo]        0.1012      0.014      7.195      0.000       0.074       0.129
# C(educacao, Treatment(2))[T.Superior incompleto]     -0.0601      0.032     -1.874      0.061      -0.123       0.003
# C(estado_civil)[T.Separado]                           0.3366      0.111      3.021      0.003       0.118       0.555
# C(estado_civil)[T.Solteiro]                           0.2529      0.109      2.319      0.020       0.039       0.467
# C(estado_civil)[T.União]                             -0.0456      0.025     -1.811      0.070      -0.095       0.004
# C(estado_civil)[T.Viúvo]                              0.4040      0.116      3.493      0.000       0.177       0.631
# C(tipo_residencia, Treatment(1))[T.Aluguel]           0.0231      0.054      0.426      0.670      -0.083       0.129
# C(tipo_residencia, Treatment(1))[T.Com os pais]      -0.0050      0.029     -0.171      0.865      -0.062       0.052
# C(tipo_residencia, Treatment(1))[T.Comunitário]      -0.0636      0.091     -0.697      0.486      -0.242       0.115
# C(tipo_residencia, Treatment(1))[T.Estúdio]           0.1202      0.084      1.431      0.153      -0.044       0.285
# C(tipo_residencia, Treatment(1))[T.Governamental]    -0.0063      0.039     -0.160      0.873      -0.083       0.070
# id_cliente                                        -2.947e-06   1.37e-06     -2.157      0.031   -5.63e-06   -2.69e-07
# qtd_filhos                                           -0.2823      0.108     -2.612      0.009      -0.494      -0.070
# tempo_emprego                                         0.0636      0.001     63.957      0.000       0.062       0.066
# qt_pessoas_residencia                                 0.2942      0.108      2.726      0.006       0.083       0.506
# ==============================================================================
# Omnibus:                        0.887   Durbin-Watson:                   2.027
# Prob(Omnibus):                  0.642   Jarque-Bera (JB):                0.865
# Skew:                           0.019   Prob(JB):                        0.649
# Kurtosis:                       3.015   Cond. No.                     4.85e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.85e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# Notas da etapa 1:
# Para a grandiosa maioria das variáveis, o nosso p-value nos diz que as mesmas não são relevantes na nossa análise. Pela altíssima quantidade de variáveis envolvidas, eu levantei a hipótese de que seria melhor usar um p-value de .01, e fui pesquisar para verificar se essa hipótese era considerada correta, e obtive positiva (quanto mais variáveis, mais recomendável um p-value menor...). Então, usando este crivo, manteremos no modelo as variáveis: Sexo, posse de veículo, posse de imóvel, tipo de renda, educação, estado civil, qtd de filhos, tempo de emprego e qt pessoas na residência. Reajustaremos, e compararemos os modelos.
#
# Segue o código da etapa 2:

# %%
colunas = list(df.columns)
regr2 = smf.ols("""np.log(renda) ~ C(sexo) + posse_de_veiculo + posse_de_imovel +  C(tipo_renda) + C(educacao, Treatment(2)) + 
                C(estado_civil) + tempo_emprego  + qt_pessoas_residencia""", data = df).fit()
regr2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          np.log(renda)   R-squared:                       0.355
# Model:                            OLS   Adj. R-squared:                  0.354
# Method:                 Least Squares   F-statistic:                     401.2
# Date:                Fri, 09 Aug 2024   Prob (F-statistic):               0.00
# Time:                        17:20:14   Log-Likelihood:                -13595.
# No. Observations:               12427   AIC:                         2.723e+04
# Df Residuals:                   12409   BIC:                         2.736e+04
# Df Model:                          17
# Covariance Type:            nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# Intercept                                            7.3015      0.028    261.925      0.000       7.247       7.356
# C(sexo)[T.M]                                         0.7825      0.015     53.549      0.000       0.754       0.811
# posse_de_veiculo[T.True]                             0.0399      0.014      2.823      0.005       0.012       0.068
# posse_de_imovel[T.True]                              0.0909      0.014      6.640      0.000       0.064       0.118
# C(tipo_renda)[T.Bolsista]                            0.2578      0.242      1.067      0.286      -0.216       0.731
# C(tipo_renda)[T.Empresário]                          0.1530      0.015     10.245      0.000       0.124       0.182
# C(tipo_renda)[T.Pensionista]                        -0.3265      0.242     -1.351      0.177      -0.800       0.147
# C(tipo_renda)[T.Servidor público]                    0.0578      0.022      2.598      0.009       0.014       0.101
# C(educacao, Treatment(2))[T.Primário]               -0.0080      0.072     -0.111      0.912      -0.149       0.133
# C(educacao, Treatment(2))[T.Pós graduação]           0.1257      0.142      0.883      0.377      -0.153       0.405
# C(educacao, Treatment(2))[T.Superior completo]       0.0974      0.014      7.052      0.000       0.070       0.125
# C(educacao, Treatment(2))[T.Superior incompleto]    -0.0599      0.032     -1.875      0.061      -0.122       0.003
# C(estado_civil)[T.Separado]                          0.0577      0.029      1.964      0.050       0.000       0.115
# C(estado_civil)[T.Solteiro]                         -0.0252      0.023     -1.093      0.274      -0.070       0.020
# C(estado_civil)[T.União]                            -0.0453      0.025     -1.803      0.071      -0.095       0.004
# C(estado_civil)[T.Viúvo]                             0.1206      0.043      2.809      0.005       0.036       0.205
# tempo_emprego                                        0.0637      0.001     64.296      0.000       0.062       0.066
# qt_pessoas_residencia                                0.0121      0.008      1.447      0.148      -0.004       0.029
# ==============================================================================
# Omnibus:                        0.591   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.744   Jarque-Bera (JB):                0.570
# Skew:                           0.015   Prob(JB):                        0.752
# Kurtosis:                       3.014   Cond. No.                         389.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Como eu li depois lá em cima que já havia sido especificado o p-value para ser utilizado, vou deixar aqui a versão com a exclusão apenas dos p-values maiores que .05...

# %%
regr1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          np.log(renda)   R-squared:                       0.357
# Model:                            OLS   Adj. R-squared:                  0.355
# Method:                 Least Squares   F-statistic:                     180.9
# Date:                Fri, 09 Aug 2024   Prob (F-statistic):               0.00
# Time:                        17:20:45   Log-Likelihood:                -13574.
# No. Observations:               12427   AIC:                         2.723e+04
# Df Residuals:                   12388   BIC:                         2.751e+04
# Df Model:                          38
# Covariance Type:            nonrobust
# =====================================================================================================================
#                                                         coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------
# Intercept                                             6.7514      0.219     30.896      0.000       6.323       7.180
# C(data_ref)[T.2015-02-01]                             0.0019      0.035      0.053      0.958      -0.068       0.071
# C(data_ref)[T.2015-03-01]                             0.0483      0.036      1.358      0.175      -0.021       0.118
# C(data_ref)[T.2015-04-01]                             0.0487      0.035      1.372      0.170      -0.021       0.118
# C(data_ref)[T.2015-05-01]                            -0.0192      0.035     -0.544      0.586      -0.089       0.050
# C(data_ref)[T.2015-06-01]                             0.0713      0.036      2.008      0.045       0.002       0.141
# C(data_ref)[T.2015-07-01]                             0.0285      0.035      0.805      0.421      -0.041       0.098
# C(data_ref)[T.2015-08-01]                            -0.0004      0.036     -0.011      0.991      -0.070       0.069
# C(data_ref)[T.2015-09-01]                            -0.0092      0.035     -0.259      0.795      -0.078       0.060
# C(data_ref)[T.2015-10-01]                             0.0223      0.036      0.626      0.531      -0.047       0.092
# C(data_ref)[T.2015-11-01]                             0.0224      0.036      0.630      0.528      -0.047       0.092
# C(data_ref)[T.2015-12-01]                             0.0720      0.036      2.017      0.044       0.002       0.142
# C(data_ref)[T.2016-01-01]                            -0.0391      0.036     -1.101      0.271      -0.109       0.031
# C(data_ref)[T.2016-02-01]                            -0.0039      0.036     -0.110      0.912      -0.074       0.066
# C(data_ref)[T.2016-03-01]                            -0.0391      0.036     -1.091      0.275      -0.109       0.031
# C(sexo)[T.M]                                          0.7826      0.015     53.418      0.000       0.754       0.811
# posse_de_veiculo[T.True]                              0.0384      0.014      2.708      0.007       0.011       0.066
# posse_de_imovel[T.True]                               0.0873      0.014      6.225      0.000       0.060       0.115
# C(tipo_renda)[T.Bolsista]                             0.2336      0.242      0.966      0.334      -0.240       0.707
# C(tipo_renda)[T.Empresário]                           0.1537      0.015     10.280      0.000       0.124       0.183
# C(tipo_renda)[T.Pensionista]                         -0.3042      0.242     -1.258      0.208      -0.778       0.170
# C(tipo_renda)[T.Servidor público]                     0.0561      0.022      2.521      0.012       0.012       0.100
# C(educacao, Treatment(2))[T.Primário]                 0.0021      0.072      0.030      0.976      -0.139       0.143
# C(educacao, Treatment(2))[T.Pós graduação]            0.1224      0.142      0.860      0.390      -0.157       0.401
# C(educacao, Treatment(2))[T.Superior completo]        0.1012      0.014      7.195      0.000       0.074       0.129
# C(educacao, Treatment(2))[T.Superior incompleto]     -0.0601      0.032     -1.874      0.061      -0.123       0.003
# C(estado_civil)[T.Separado]                           0.3366      0.111      3.021      0.003       0.118       0.555
# C(estado_civil)[T.Solteiro]                           0.2529      0.109      2.319      0.020       0.039       0.467
# C(estado_civil)[T.União]                             -0.0456      0.025     -1.811      0.070      -0.095       0.004
# C(estado_civil)[T.Viúvo]                              0.4040      0.116      3.493      0.000       0.177       0.631
# C(tipo_residencia, Treatment(1))[T.Aluguel]           0.0231      0.054      0.426      0.670      -0.083       0.129
# C(tipo_residencia, Treatment(1))[T.Com os pais]      -0.0050      0.029     -0.171      0.865      -0.062       0.052
# C(tipo_residencia, Treatment(1))[T.Comunitário]      -0.0636      0.091     -0.697      0.486      -0.242       0.115
# C(tipo_residencia, Treatment(1))[T.Estúdio]           0.1202      0.084      1.431      0.153      -0.044       0.285
# C(tipo_residencia, Treatment(1))[T.Governamental]    -0.0063      0.039     -0.160      0.873      -0.083       0.070
# id_cliente                                        -2.947e-06   1.37e-06     -2.157      0.031   -5.63e-06   -2.69e-07
# qtd_filhos                                           -0.2823      0.108     -2.612      0.009      -0.494      -0.070
# tempo_emprego                                         0.0636      0.001     63.957      0.000       0.062       0.066
# qt_pessoas_residencia                                 0.2942      0.108      2.726      0.006       0.083       0.506
# ==============================================================================
# Omnibus:                        0.887   Durbin-Watson:                   2.027
# Prob(Omnibus):                  0.642   Jarque-Bera (JB):                0.865
# Skew:                           0.019   Prob(JB):                        0.649
# Kurtosis:                       3.015   Cond. No.                     4.85e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.85e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# As variaveis a serem eliminadas são: tipo de residencia

# %%
colunas = list(df.columns)
regr3 = smf.ols("""np.log(renda) ~ C(data_ref) + id_cliente + C(sexo) + posse_de_veiculo + posse_de_imovel + qtd_filhos + 
                C(tipo_renda) + C(educacao, Treatment(2)) + C(estado_civil) + tempo_emprego 
                + qt_pessoas_residencia""", data = df).fit()
regr3.summary()


# Adiciono aqui esta nota... seguindo o padrão especificado no enunciado (p-value menor que .05) a única categoria a ser eliminada foi a
# do tipo de residencia. O professor, por alto, no vídeo, fala que poderíamos juntar categorias na hora de fazer a análise quando apenas
# algumas dummies forem relevantes, mas, no entanto, ele não diz como fazer isso, e nem o enunciado especifica que deveriamos fazê-lo...

# Em todo caso, em ambos os exemplos, o nosso R-squared ajustado parece não ter se incomodado muito com o número de variáveis, então,
# o nosso trabalho em reduzir o número de variáveis não seria de muita utilidade, de todo modo... como o R-squared pro R-squared ajustado
# possui uma diferença de apenas .02, quase irrelevante, o nosso modelo só poderia ser dito melhor caso o noso R-squared permanecesse em
# .3
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          np.log(renda)   R-squared:                       0.357
# Model:                            OLS   Adj. R-squared:                  0.355
# Method:                 Least Squares   F-statistic:                     208.3
# Date:                Fri, 09 Aug 2024   Prob (F-statistic):               0.00
# Time:                        17:24:40   Log-Likelihood:                -13575.
# No. Observations:               12427   AIC:                         2.722e+04
# Df Residuals:                   12393   BIC:                         2.747e+04
# Df Model:                          33
# Covariance Type:            nonrobust
# ====================================================================================================================
#                                                        coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------------
# Intercept                                            6.7502      0.218     30.898      0.000       6.322       7.178
# C(data_ref)[T.2015-02-01]                            0.0020      0.035      0.056      0.956      -0.068       0.072
# C(data_ref)[T.2015-03-01]                            0.0486      0.036      1.367      0.172      -0.021       0.118
# C(data_ref)[T.2015-04-01]                            0.0486      0.035      1.369      0.171      -0.021       0.118
# C(data_ref)[T.2015-05-01]                           -0.0190      0.035     -0.537      0.591      -0.088       0.050
# C(data_ref)[T.2015-06-01]                            0.0720      0.036      2.026      0.043       0.002       0.142
# C(data_ref)[T.2015-07-01]                            0.0292      0.035      0.825      0.409      -0.040       0.099
# C(data_ref)[T.2015-08-01]                           -0.0002      0.036     -0.005      0.996      -0.070       0.069
# C(data_ref)[T.2015-09-01]                           -0.0097      0.035     -0.274      0.784      -0.079       0.060
# C(data_ref)[T.2015-10-01]                            0.0233      0.036      0.655      0.512      -0.046       0.093
# C(data_ref)[T.2015-11-01]                            0.0228      0.036      0.642      0.521      -0.047       0.092
# C(data_ref)[T.2015-12-01]                            0.0722      0.036      2.024      0.043       0.002       0.142
# C(data_ref)[T.2016-01-01]                           -0.0385      0.036     -1.084      0.278      -0.108       0.031
# C(data_ref)[T.2016-02-01]                           -0.0035      0.036     -0.099      0.921      -0.073       0.066
# C(data_ref)[T.2016-03-01]                           -0.0392      0.036     -1.094      0.274      -0.109       0.031
# C(sexo)[T.M]                                         0.7840      0.015     53.677      0.000       0.755       0.813
# posse_de_veiculo[T.True]                             0.0385      0.014      2.723      0.006       0.011       0.066
# posse_de_imovel[T.True]                              0.0876      0.014      6.375      0.000       0.061       0.115
# C(tipo_renda)[T.Bolsista]                            0.2341      0.242      0.969      0.333      -0.240       0.708
# C(tipo_renda)[T.Empresário]                          0.1546      0.015     10.359      0.000       0.125       0.184
# C(tipo_renda)[T.Pensionista]                        -0.3042      0.242     -1.258      0.208      -0.778       0.170
# C(tipo_renda)[T.Servidor público]                    0.0575      0.022      2.585      0.010       0.014       0.101
# C(educacao, Treatment(2))[T.Primário]               -0.0024      0.072     -0.033      0.973      -0.143       0.138
# C(educacao, Treatment(2))[T.Pós graduação]           0.1219      0.142      0.857      0.392      -0.157       0.401
# C(educacao, Treatment(2))[T.Superior completo]       0.1009      0.014      7.192      0.000       0.073       0.128
# C(educacao, Treatment(2))[T.Superior incompleto]    -0.0609      0.032     -1.903      0.057      -0.124       0.002
# C(estado_civil)[T.Separado]                          0.3368      0.111      3.024      0.003       0.118       0.555
# C(estado_civil)[T.Solteiro]                          0.2533      0.109      2.323      0.020       0.040       0.467
# C(estado_civil)[T.União]                            -0.0448      0.025     -1.783      0.075      -0.094       0.004
# C(estado_civil)[T.Viúvo]                             0.4032      0.116      3.487      0.000       0.177       0.630
# id_cliente                                       -2.958e-06   1.37e-06     -2.166      0.030   -5.63e-06   -2.82e-07
# qtd_filhos                                          -0.2821      0.108     -2.611      0.009      -0.494      -0.070
# tempo_emprego                                        0.0637      0.001     64.227      0.000       0.062       0.066
# qt_pessoas_residencia                                0.2941      0.108      2.726      0.006       0.083       0.506
# ==============================================================================
# Omnibus:                        0.908   Durbin-Watson:                   2.027
# Prob(Omnibus):                  0.635   Jarque-Bera (JB):                0.886
# Skew:                           0.019   Prob(JB):                        0.642
# Kurtosis:                       3.015   Cond. No.                     4.85e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.85e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
